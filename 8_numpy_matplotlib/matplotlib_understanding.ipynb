# %% [markdown]
# Matplotlib understanding

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt



#plots
x=[10,20,30]
y=[10,20,30]

'''   
(10,10),(20,20),(30,30)
'''

plt.plot(x,y)

# %%
import random
print(random.randrange(1,10))
#Create X and y lists with random number ranging from 1,10. both should have 20 elements
X=[random.randrange(1,101) for i in range(1,20)]
Y=[random.randrange(1,101) for i in range(1,20)]


plt.plot(X,Y,color="RED")
plt.xlabel(' X point')

plt.ylabel(' y point')

plt.title('Random plots')
# Out:
# 4
# Text(0.5, 1.0, 'Niwesh')

# %% [markdown]
# '''
# x=[get numbers from -100 to 100]
# y=create a function that does following
# y=x**2/4*a (a=1 by default)
# plot x and y check what kind of graph it becomes
#
# '''

# %%
a=[i for i in range(-100,100)]
Y=lambda x:(x**2)/4

b=[Y(i) for i in x]



plt.plot(a,b,color="RED")

# %% [markdown]
# Scatter plot

# %%
students=['Ram','Sita','Hari','Prasad']
maths=[50,60,70,80]
science=[80,60,50,90]

plt.scatter(maths,science,color='RED')
plt.grid()
plt.xlabel('science score')
plt.ylabel('Math score')
# Out:
# Text(0, 0.5, 'Math score')

# %%
''' 
1st phase : 

 Wap that asks for N (number of students to enter record)
 first it asks the name of the student, marks in mathematics, marks in science
 create a dataframe at the end and then dump it as data_students.csv


2nd phase:
 then in another cell read the csv file from data student.csv
 scatter plot the marks of each students in mathematics and science
'''
# Out:
# ' \n1st phase : \n\n Wap that asks for N (number of students to enter record)\n first it asks the name of the student, marks in mathematics, marks in science\n create a dataframe at the end and then dump it as data_students.csv\n\n\n2nd phase:\n then in another cell read the csv file from data student.csv\n scatter plot the marks of each students in mathematics and science\n'

# %%
import matplotlib.pyplot as plt
import numpy as np

sujects=[]
students=[]

N=int(input('Enter total number'))

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# comparision of 2 graphs in matplotlib

# %%
def stock_price_calc(x,m=4,c=10):
    return m*x+c

x=[i for i in range(1,13) ]
y_1=[stock_price_calc(i) for i in x]

y_2=[stock_price_calc(i,m=-3,c=5) for i in x]
y_3=[stock_price_calc(i,m=-6,c=1) for i in x]

plt.plot(x,y_1)
plt.plot(x,y_2)

plt.plot(x,y_3)
plt.legend('2005','2025','2023')
plt.xlabel('Months')
plt.ylabel('Stock price')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       7 y_2=[stock_price_calc(i,m=-3,c=5) for i in x]
#       9 plt.plot(x,y_1)
# ---> 10 plt.legend('2005','2025','2023')
#      11 plt.xlabel('Months')
#      12 plt.ylabel('Stock price')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\pyplot.py:3502, in legend(*args, **kwargs)
#    3500 @_copy_docstring_and_deprecators(Axes.legend)
#    3501 def legend(*args, **kwargs) -> Legend:
# -> 3502     return gca().legend(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\axes\_axes.py:341, in Axes.legend(self, *args, **kwargs)
#     223 @_docstring.dedent_interpd
#     224 def legend(self, *args, **kwargs):
# ...
